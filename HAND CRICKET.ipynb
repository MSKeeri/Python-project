# %%
import random
def batting1():
    global x
    global total
    total=0
    while True:
        game=input("what's the number: ")
        if game not in '0123456':
            print('number wants to be less than 7')
        else:
            game=int(game)
            if game<=6:
                computer=random.randint(0,6)
                total=total+game

                print('yous bats:',game)
                print('computer bowls:',computer)
                if game!=computer:
                    print('current run is ',total)
                elif game==computer:
                    x=total-game
                    print('you are out')
                    print(' your total run is ',x)
                    print('***-------------***')
                    break
                
def bowling1():
    global y
    global total2
    total2=0
    while True:
        game=input("what's the number: ")
        if game not in '0123456':
            print('number wants to be less than 7')
        else:
            game=int(game)
            if game<=6:
                computer=random.randint(0,6)
                total2=total2+computer

                print('you bowls:',game)
                print('computer bats:',computer)
                if game!=computer:
                    print('current run is ',total2)
                elif game==computer:
                    y=total2-game
                    print('computer is  out')
                    print("computer's total run is ",y)
                    print('***-------------***')
                    break

                    
def batting2():
    global x
    global total
    total=0
    while total<total2:
        game=input("what's the number: ")
        if game not in '0123456':
            print('number wants to be less than 7')
        else:
            game=int(game)
            if game<=6:
                computer=random.randint(0,6)
                total=total+game

                print('yous bats:',game)
                print('computer bowls:',computer)
                if game!=computer:
                    print('current run is ',total)
                elif game==computer:
                    x=total-game
                    print('you are out')
                    print(' your total run is ',x)
                    print('***-------------***')
                    break
                
def bowling2():
    global y
    global total2
    total2=0
    while total2<total:
        game=input("what's the number: ")
        if game not in '0123456':
            print('number wants to be less than 7')
        else:
            game=int(game)
            if game<=6:
                computer=random.randint(0,6)
                total2=total2+computer

                print('you bowls:',game)
                print('computer bats:',computer)
                if game!=computer:
                    print('current run is ',total2)
                elif game==computer:
                    y=total2-game
                    print('computer is  out')
                    print("computer's total run is ",y)
                    print('***-------------***')
                    break
    
                    
                    
                    
def gaming():
    player1=input("what's your name? ")
    k=[player1,'computer']
    b=random.choice(k)
    print(b,'choses batting')
    if b==player1:
        batting1()
        bowling2()
        if x==y:
            print('draw')
        elif total2>x:
            print('computer won')
        else:
            print(f'{player1} won')
    elif b=='computer':
        bowling1()
        batting2()
        if x==y:
            print('draw')
        elif total>y:
            print(f'{player1} won')
        else:
            print('computer won')
            
    

    
gaming()
