# %%
from IPython.display import clear_output
d={1:" ",2:" ",3:" ",
   4:" ",5:" ",6:" ",
   7:" ",8:" ",9:" "}
import random
player1=input('player1: ')
player2=input('player2: ')
m=[player1,player2]
k=random.choice(m)

print('first player is: ',k)


def display(d):
    print(f'{d[1]}|{d[2]}|{d[3]}')
    print('-'*5)
    print(f'{d[4]}|{d[5]}|{d[6]}')
    print('-'*5)
    print(f'{d[7]}|{d[8]}|{d[9]}')
mark='X'
def win(a):
    if d[1]==d[2]==d[3]=='X' or d[1]==d[2]==d[3]=='O':
        return True
    elif d[4]==d[5]==d[6]=='X' or  d[4]==d[5]==d[6]=='O':
        return True
    elif d[7]==d[8]==d[9]=='X' or  d[7]==d[8]==d[9]=='O':
        return True 
    elif d[1]==d[4]==d[7]=='X' or  d[1]==d[4]==d[7]=='O':
        return True
    elif d[2]==d[5]==d[8]=='X' or  d[2]==d[5]==d[8]=='O':  
        return True
    elif d[3]==d[6]==d[9]=='X' or d[3]==d[6]==d[9]=='O': 
        return True
    elif d[1]==d[5]==d[9]=='X'or  d[1]==d[5]==d[9]=='O':
        return True
    elif d[3]==d[5]==d[7]=='X'or  d[3]==d[5]==d[7]=='O':
        return True
    
    elif(d[1]!=' 'and d[2]!=' 'and d[3]!=' 'and d[4]!=' 'and d[5]!=' 'and d[6]!=' 'and d[7]!=' 'and d[8]!=' 'and d[9]!=' '):
        return 'draw'
        draw = True
    

while True:
    draw=False
    s=input('pls enter the position between 1 to 9')
    if s=='1' or s=='2' or s=='3' or s=='4'or s=='5' or s=='6' or s=='7' or s=='8' or s=='9':
        s=int(s)
        if mark=='X':
            if d[s]!=' ': 
                continue
            d[s]='X'
            mark='O'
            clear_output()
        
            
            win(d)
            display(d)

        elif mark=='O':
            if d[s]!=' ':
                continue
            d[s]='O'
            mark='X'
            clear_output()
            won = win(d)
            if won:
                if k==player1:
                    print('winner is ',player2)
                else:
                    print('winner is ',player1)
                    
                
                break
            
display(d)
# Out:
# winner is  a
# X|X|O
# -----
# X|O|O
# -----
# X|O|
